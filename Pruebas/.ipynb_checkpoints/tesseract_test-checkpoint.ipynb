# %%
from PIL import Image
import pytesseract

# %%
im1 = Image.open("imagenes/i4.jpg")

# %%
im1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=648x1144 at 0x10DEA2BE0>

# %%
text1 = pytesseract.image_to_string(im1, lang = "spa")

# %%
print(text1)
# Out:
# ba
# !
#
# EA]
# Question 4 of 10
#
# ¿Cuál de estos lugares NO está en la lista
# del patrimonio mundial de la UNESCO?
#
# El Tajín
#
# Ciudad del Vaticano
#
# El Cañón del Antílope

# %%
im5 = Image.open("Imagenes/i5.png")

# %%
im5
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1225x781 at 0x11C880EF0>
